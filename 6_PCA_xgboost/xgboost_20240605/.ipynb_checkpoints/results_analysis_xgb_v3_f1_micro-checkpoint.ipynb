# %%
# variation of skill with season
# variation of skill with initial WR
# variation of skill with ENSO

import numpy as np
import xarray as xr
import pandas as pd
import copy
from datetime import datetime, timedelta
# import visualkeras
# import tensorflow as tf
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

from sklearn.utils.class_weight import compute_class_weight
import sys
import os
import joblib
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import glob 

sys.path.append("/glade/u/home/jhayron/WR_Predictability/3_MLModels/")
from sklearn import datasets, ensemble
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # persistence performance

# %%
wr_series = pd.read_csv('/glade/work/jhayron/Data4Predictability/WR_Series_20231120.csv',\
                index_col=0,names=['week0'],skiprows=1,parse_dates=True)
for wk in range(2,10):
    series_temp = copy.deepcopy(wr_series["week0"])
    series_temp.index = series_temp.index - timedelta(weeks = wk-1)
    series_temp.name = f'week{wk-1}'
    if wk==2:
        df_shifts = pd.concat([pd.DataFrame(wr_series["week0"]),pd.DataFrame(series_temp)],axis=1)  
    else:
        df_shifts = pd.concat([df_shifts,pd.DataFrame(series_temp)],axis=1)

# %%
acc_persistence = []

for wk in range(1,9):
    df_temp = df_shifts[[f'week{0}',f'week{wk}']].dropna()#['2016':'2020']
    acc_persistence.append(f1_score(df_temp[f'week{wk}'],df_temp[f'week{0}'],average='micro'))

# %%
acc_persistence = np.array(acc_persistence)

# %% [markdown]
# # performance xgb

# %%
path_results = 'results/'

# %%
list_folders = np.sort(glob.glob('/glade/u/home/jhayron/WR_Predictability/6_PCA_xgboost/figures_detrended_20/*/'))
list_vars = [list_folders[i].split('/')[-2] for i in range(len(list_folders))]

for ivar,var in enumerate(list_vars):
    print(ivar,var)
# Out:
# 0 IC_SODA
# 1 IT_SODA
# 2 MLD_SODA
# 3 OHC100_SODA
# 4 OHC200_SODA
# 5 OHC300_SODA
# 6 OHC50_SODA
# 7 OHC700_SODA
# 8 OLR_ERA5
# 9 SD_ERA5
# 10 SSH_SODA
# 11 SST_SODA
# 12 STL_1m_ERA5
# 13 STL_28cm_ERA5
# 14 STL_7cm_ERA5
# 15 STL_full_ERA5
# 16 SWVL_1m_ERA5
# 17 SWVL_28cm_ERA5
# 18 SWVL_7cm_ERA5
# 19 SWVL_full_ERA5
# 20 U10_ERA5
# 21 U200_ERA5
# 22 Z500_ERA5
# 23 Z500_ERA5_Region

# %%
indices_atmosphere = np.array([8,20,21,22])
indices_land = np.array([9,12,13,14,15,16,17,18,19])
# indices_land = np.array([9,12,13,14,15,16,18,19])
indices_ocean = np.array([0,1,2,3,4,5,6,7,10,11])

# %%
# Define weeks
weeks = np.arange(1, 9)

# %% [markdown]
# ## Evaluate atmospheric variables

# %%
def compute_accuracy_and_range(results_temp):
    accuracy_iterations = []
    for _ in range(30):  # Adjust the number of iterations as needed
        sample_indices = np.random.choice(results_temp.index, size=int(0.33*len(results_temp)), replace=False)
        sampled_data = results_temp.loc[sample_indices]
        accuracy_iterations.append(f1_score(sampled_data['y_true'], sampled_data['y_predicted'],average='micro'))
    accuracy_mean = np.mean(accuracy_iterations)
    accuracy_std = np.std(accuracy_iterations)
    error_range = 1. * accuracy_std  # Assuming a 95% confidence interval
    return accuracy_mean, error_range

def process_results(indices, list_vars, path_results):
    all_accs = []
    all_ranges = []
    weeks = np.arange(1, 9)
    
    for ivar in range(len(indices)):
        name_temp = list_vars[indices[ivar]]
        acc_temp = []
        acc_range_temp = []
        
        for week in weeks:
            results_temp = pd.read_csv(f'{path_results}results_{name_temp}_week{week}.csv', index_col=0, parse_dates=True)
            acc_mean, acc_range = compute_accuracy_and_range(results_temp)
            acc_temp.append(acc_mean)
            acc_range_temp.append(acc_range)
        
        all_accs.append(acc_temp)
        all_ranges.append(acc_range_temp)
    
    ind_max_acc = np.argmax(np.array(all_accs), axis=0)
    best_model = ['\n'.join(list_vars[indices[ind]].split('_')[:-1]) for ind in ind_max_acc]
    
    max_acc_range = [np.array(all_ranges)[ind_max_acc[i], i] for i in range(len(ind_max_acc))]
    
    best_model_all = best_model
    best_acc_all = np.max(np.array(all_accs), axis=0)
    best_acc_range_all = np.array(max_acc_range)
    mean_acc_all = np.mean(np.array(all_accs), axis=0)
    diff_acc_all = best_acc_all - mean_acc_all
    
    return all_accs, all_ranges, best_model_all, best_acc_all, best_acc_range_all, mean_acc_all, diff_acc_all
    
def plot_accuracy(weeks, all_accs, best_model, acc_persistence, list_vars, component, indices_component):
    if component == 'lnd':
        component_long = 'land'
    if component == 'atm':
        component_long = 'atmosphere'
    if component == 'ocn':
        component_long = 'ocean'

    list_vars = np.array(list_vars)
    plt.figure(figsize=(8, 6))

    # Plot individual models
    for acc_temp, name_temp in zip(all_accs, [list_vars[indices_component][i].split('_')[:-1] for i in range(len(indices_component))]):
        plt.plot(weeks, np.array(acc_temp), label='_'.join(name_temp), alpha=0.4)

    # # Plot all variables for the given component
    # acc_temp = [f1_score(pd.read_csv(f'{path_results}results_{component}_week{week}.csv', index_col=0, parse_dates=True)['y_true'],
    #                            pd.read_csv(f'{path_results}results_{component}_week{week}.csv', index_col=0, parse_dates=True)['y_predicted'],
    #                      average='micro')
    #             for week in weeks]
    # plt.plot(weeks, np.array(acc_temp), label=f'All {component_long} variables', color='k', ls='--')

    # Plot best model
    for i, j, d in zip(weeks, np.max(np.array(all_accs), axis=0), best_model):
        plt.scatter(i, j, color='k', marker='*', s=100)
        plt.text(i - 0.25, j + 0.01, s=d,fontsize=11)

    # Plot persistence
    plt.plot(weeks, acc_persistence, color='red', label='Persistence', ls='dashdot', lw=2)

    # Finalizing plot
    plt.ylim(0.17, 0.36)
    plt.xlim(0.4, 8.6)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(alpha=0.2)
    plt.ylabel('F1 Score',fontsize=14)
    plt.xlabel('Lead time [weeks]',fontsize=14)
    plt.title(f'Models based on {component_long} variables', loc='left')
    plt.legend(bbox_to_anchor=(1, 1.0), fontsize=14, ncol=2)
    plt.savefig(f'figures/f1_{component}.png', bbox_inches='tight')
    plt.show()

# %%
# Call the function with necessary arguments for ocean
all_accs_ocean, all_ranges_ocean, best_model_ocean, best_acc_ocean, best_acc_range_ocean, mean_acc_ocean, diff_acc_ocean = process_results(indices_ocean, list_vars, path_results)

# Call the function with necessary arguments for land
all_accs_land, all_ranges_land, best_model_land, best_acc_land, best_acc_range_land, mean_acc_land, diff_acc_land = process_results(indices_land, list_vars, path_results)

# Call the function with necessary arguments for atmosphere
all_accs_atmosphere, all_ranges_atmosphere, best_model_atmosphere, best_acc_atmosphere, best_acc_range_atmosphere, mean_acc_atmosphere, diff_acc_atmosphere = process_results(indices_atmosphere, list_vars, path_results)

# %%
# Example usage for ocean component
component = 'ocn'
plot_accuracy(weeks, all_accs_ocean, best_model_ocean, acc_persistence, list_vars, component, indices_ocean)

# Example usage for land component
component = 'lnd'
plot_accuracy(weeks, all_accs_land, best_model_land, acc_persistence, list_vars, component, indices_land)

# Example usage for atmosphere component
component = 'atm'
plot_accuracy(weeks, all_accs_atmosphere, best_model_atmosphere, acc_persistence, list_vars, component, indices_atmosphere)

# %%
plt.figure(figsize=(8, 6))

plt.plot(weeks,best_acc_atmosphere,label=f'Best atmosphere model',color='mediumorchid',lw=2)
plt.scatter(weeks,best_acc_atmosphere,color='mediumorchid')#, s=diff*100)
plt.plot(weeks,best_acc_ocean,label=f'Best ocean model',color='darkblue',lw=2)
plt.scatter(weeks,best_acc_ocean,color='darkblue')
plt.plot(weeks,best_acc_land,label=f'Best land model',color='darkorange',lw=2)
plt.scatter(weeks,best_acc_land,color='darkorange')

plt.fill_between(weeks, best_acc_atmosphere - best_acc_range_atmosphere, 
                 best_acc_atmosphere + best_acc_range_atmosphere, color='mediumorchid', alpha=0.07)
plt.fill_between(weeks, best_acc_ocean - best_acc_range_ocean, 
                 best_acc_ocean + best_acc_range_ocean, color='darkblue', alpha=0.07)
plt.fill_between(weeks, best_acc_land - best_acc_range_land, 
                 best_acc_land + best_acc_range_land, color='darkorange', alpha=0.07)

# Plot best model
for i, j, d in zip(weeks, np.max(np.array(all_accs_atmosphere), axis=0), best_model_atmosphere):
    plt.text(i - 0.25, 0.18, s=d, color = 'mediumorchid',fontsize=11)
for i, j, d in zip(weeks, np.max(np.array(all_accs_ocean), axis=0), best_model_ocean):
    plt.text(i - 0.25, 0.17, s=d, color = 'darkblue',fontsize=11)
for i, j, d in zip(weeks, np.max(np.array(all_accs_land), axis=0), best_model_land):
    plt.text(i - 0.25,  0.155, s=d, color = 'darkorange',fontsize=11)


plt.plot(weeks, acc_persistence, color='red', label='Persistence', ls='dashdot', lw=2)
plt.xlim(0.4, 8.6)
plt.ylim(0.15, 0.36)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(alpha=0.2)
plt.ylabel('F1 Score',fontsize=14)
plt.xlabel('Lead time [weeks]',fontsize=14)
plt.legend(bbox_to_anchor=(1, 1.0), fontsize=14)
plt.savefig('figures/f1_3comps.png',bbox_inches='tight')

# %%
best_model_land
# Out:
# ['SWVL\n28cm',
#  'SWVL\n1m',
#  'STL\nfull',
#  'SD',
#  'SWVL\n1m',
#  'SWVL\n1m',
#  'STL\n28cm',
#  'SWVL\n1m']

# %% [markdown]
# # Check for seasons

# %%
indices_seasons = {'Winter':[12,1,2],
                   'Spring':[3,4,5],
                   'Summer':[6,7,8],
                   'Fall':[9,10,11]}

acc_persistence_seasons = {}
for season in indices_seasons.keys():
    acc_persistence_temp = []
    for wk in range(1,9):
        df_temp = df_shifts[[f'week{0}',f'week{wk}']].dropna()
        df_temp = df_temp[(df_temp.index.month==indices_seasons[season][0])|\
                                    (df_temp.index.month==indices_seasons[season][1])|\
                                    (df_temp.index.month==indices_seasons[season][2])]
        acc_persistence_temp.append(f1_score(df_temp[f'week{wk}'],df_temp[f'week{0}'],average='micro'))
    acc_persistence_seasons[season] = acc_persistence_temp

# %%
def process_results_with_seasons(indices, list_vars, path_results, indices_seasons, season):
    all_accs = []
    all_ranges = []
    weeks = np.arange(1, 9)
    
    for ivar in range(len(indices)):
        name_temp = list_vars[indices[ivar]]
        acc_temp = []
        acc_range_temp = []
        
        for week in weeks:
            results_temp = pd.read_csv(f'{path_results}results_{name_temp}_week{week}.csv', index_col=0, parse_dates=True)
            results_temp = results_temp[(results_temp.index.month==indices_seasons[season][0])|\
                            (results_temp.index.month==indices_seasons[season][1])|\
                            (results_temp.index.month==indices_seasons[season][2])]
            
            acc_mean, acc_range = compute_accuracy_and_range(results_temp)
            acc_temp.append(acc_mean)
            acc_range_temp.append(acc_range)
        
        all_accs.append(acc_temp)
        all_ranges.append(acc_range_temp)
    
    ind_max_acc = np.argmax(np.array(all_accs), axis=0)
    best_model = ['\n'.join(list_vars[indices[ind]].split('_')[:-1]) for ind in ind_max_acc]
    
    max_acc_range = [np.array(all_ranges)[ind_max_acc[i], i] for i in range(len(ind_max_acc))]
    
    best_model_all = best_model
    best_acc_all = np.max(np.array(all_accs), axis=0)
    best_acc_range_all = np.array(max_acc_range)
    mean_acc_all = np.mean(np.array(all_accs), axis=0)
    diff_acc_all = best_acc_all - mean_acc_all
    
    return all_accs, all_ranges, best_model_all, best_acc_all, best_acc_range_all, mean_acc_all, diff_acc_all

# %%
# Call the function with necessary arguments for each season
for season in indices_seasons.keys():
    best_accs = {}
    best_acc_ranges = {}
    best_names = {}
    component_names = ['atmosphere','ocean','land']
    for indices_component, component in zip([indices_atmosphere, indices_ocean, indices_land], component_names):
        all_accs_temp, all_ranges_temp, best_model_all, best_acc_all, \
            best_acc_range_all, mean_acc_all, diff_acc_all = \
                process_results_with_seasons(indices_component, list_vars, path_results, indices_seasons, season)
        best_accs[component] = best_acc_all
        best_acc_ranges[component] = best_acc_range_all
        best_names[component] = best_model_all
        print(best_names[component])

    plt.figure(figsize=(8, 7))
    
    plt.plot(weeks,best_accs['atmosphere'],label=f'Best atmosphere model',color='mediumorchid',lw=2)
    plt.scatter(weeks,best_accs['atmosphere'],color='mediumorchid')#, s=diff*100)
    plt.plot(weeks,best_accs['ocean'],label=f'Best ocean model',color='darkblue',lw=2)
    plt.scatter(weeks,best_accs['ocean'],color='darkblue')
    plt.plot(weeks,best_accs['land'],label=f'Best land model',color='darkorange',lw=2)
    plt.scatter(weeks,best_accs['land'],color='darkorange')
    
    plt.fill_between(weeks, best_accs['atmosphere'] - best_acc_ranges['atmosphere'], 
                     best_accs['atmosphere'] + best_acc_ranges['atmosphere'], color='mediumorchid', alpha=0.05)
    plt.fill_between(weeks, best_accs['ocean'] - best_acc_ranges['ocean'], 
                     best_accs['ocean'] + best_acc_ranges['ocean'], color='darkblue', alpha=0.05)
    plt.fill_between(weeks, best_accs['land'] - best_acc_ranges['land'], 
                     best_accs['land'] + best_acc_ranges['land'], color='darkorange', alpha=0.05)

    # Plot best model
    for i, j, d in zip(weeks, best_accs['atmosphere'], best_names['atmosphere']):
        plt.text(i - 0.25, 0.18, s=d, color = 'mediumorchid',fontsize=11)
    for i, j, d in zip(weeks, best_accs['ocean'], best_names['ocean']):
        plt.text(i - 0.25, 0.17, s=d, color = 'darkblue',fontsize=11)
    for i, j, d in zip(weeks, best_accs['land'], best_names['land']):
        plt.text(i - 0.25, 0.155, s=d, color = 'darkorange',fontsize=11)

    
    plt.plot(weeks, np.array(acc_persistence_seasons[season]), color='red', label='Persistence', ls='dashdot', lw=2)
    plt.xlim(0.4, 8.6)
    plt.ylim(0.15, 0.36)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(alpha=0.2)
    plt.ylabel('F1 Score',fontsize=14)
    plt.xlabel('Lead time [weeks]',fontsize=14)
    plt.legend(bbox_to_anchor=(1, 1.0), fontsize=14)
    
    plt.title(f'{season}',loc='left',fontsize=14)
    # plt.legend(bbox_to_anchor=(1, 0.25))
    plt.legend(fontsize=14)
    
    plt.savefig(f'figures/f1_3comps_{season}.png',bbox_inches='tight')
    plt.show()
    plt.close('all')
# Out:
# ['Z500', 'U200', 'U10', 'U10', 'OLR', 'U10', 'Z500', 'U200']
# ['SSH', 'SSH', 'SSH', 'OHC300', 'SST', 'OHC300', 'OHC200', 'OHC100']
# ['SWVL\n7cm', 'SD', 'STL\nfull', 'SD', 'SD', 'SWVL\n7cm', 'SWVL\n7cm', 'SWVL\n7cm']
# ['Z500', 'Z500', 'U200', 'Z500', 'Z500', 'U200', 'U200', 'U200']
# ['OHC50', 'IT', 'OHC300', 'OHC300', 'OHC100', 'SSH', 'OHC200', 'OHC300']
# ['SWVL\n28cm', 'SWVL\n1m', 'STL\nfull', 'SWVL\nfull', 'SWVL\n1m', 'SWVL\n1m', 'SWVL\nfull', 'SWVL\n28cm']
# ['Z500', 'U10', 'OLR', 'OLR', 'Z500', 'OLR', 'U10', 'OLR']
# ['OHC300', 'OHC700', 'OHC300', 'SSH', 'OHC700', 'OHC300', 'OHC100', 'OHC300']
# ['STL\nfull', 'STL\n7cm', 'SWVL\n1m', 'SWVL\n1m', 'SWVL\n1m', 'SWVL\nfull', 'STL\nfull', 'STL\n1m']
# ['Z500', 'U200', 'OLR', 'U200', 'Z500', 'U200', 'U200', 'U200']
# ['OHC100', 'SSH', 'OHC300', 'OHC300', 'OHC100', 'OHC300', 'OHC200', 'OHC50']
# ['STL\n28cm', 'STL\n1m', 'STL\n28cm', 'STL\n1m', 'SWVL\n1m', 'SWVL\n1m', 'STL\n28cm', 'STL\n7cm']

# %% [markdown]
# # Changes in predictability depending on WR

# %%
names_wr = ['WR1: AR','WR2: PT', 'WR3: GH', 'WR4: CUSH', 'WR5: Clima']

# %%
acc_persistence_wrs = {}
for iwr,wr in enumerate(names_wr):
    acc_persistence_temp = []
    for wk in range(1,9):
        df_temp = df_shifts[[f'week{0}',f'week{wk}']].dropna()
        df_temp = df_temp[(df_temp[f'week{wk}'] == iwr)|(df_temp[f'week{0}'] == iwr)]
        acc_persistence_temp.append(f1_score(df_temp[f'week{wk}'],df_temp[f'week{0}'],average='micro'))
    acc_persistence_wrs[wr] = acc_persistence_temp

# %%
def process_results_with_wr(indices, list_vars, path_results, wr_temp):
    all_accs = []
    all_ranges = []
    weeks = np.arange(1, 9)
    
    for ivar in range(len(indices)):
        name_temp = list_vars[indices[ivar]]
        acc_temp = []
        acc_range_temp = []
        
        for week in weeks:
            results_temp = pd.read_csv(f'{path_results}results_{name_temp}_week{week}.csv', index_col=0, parse_dates=True)
            results_temp = results_temp[(results_temp['y_true']==wr_temp)|(results_temp['y_predicted']==wr_temp)]
            
            acc_mean, acc_range = compute_accuracy_and_range(results_temp)
            acc_temp.append(acc_mean)
            acc_range_temp.append(acc_range)
        
        all_accs.append(acc_temp)
        all_ranges.append(acc_range_temp)
    
    ind_max_acc = np.argmax(np.array(all_accs), axis=0)
    best_model = ['\n'.join(list_vars[indices[ind]].split('_')[:-1]) for ind in ind_max_acc]
    
    max_acc_range = [np.array(all_ranges)[ind_max_acc[i], i] for i in range(len(ind_max_acc))]
    
    best_model_all = best_model
    best_acc_all = np.max(np.array(all_accs), axis=0)
    best_acc_range_all = np.array(max_acc_range)
    mean_acc_all = np.mean(np.array(all_accs), axis=0)
    diff_acc_all = best_acc_all - mean_acc_all
    
    return all_accs, all_ranges, best_model_all, best_acc_all, \
        best_acc_range_all, mean_acc_all, diff_acc_all

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Call the function with necessary arguments for each season
for weather_regime,weather_regime_name in enumerate(names_wr):
    best_accs = {}
    best_acc_ranges = {}
    best_names = {}
    component_names = ['atmosphere','ocean','land']
    for indices_component, component in zip([indices_atmosphere, indices_ocean, indices_land], component_names):
        all_accs_temp, all_ranges_temp, best_model_all, best_acc_all, \
            best_acc_range_all, mean_acc_all, diff_acc_all = \
                process_results_with_wr(indices_component, list_vars, path_results, weather_regime)
        best_accs[component] = best_acc_all
        best_acc_ranges[component] = best_acc_range_all
        best_names[component] = best_model_all
        print(best_names[component])

    plt.figure(figsize=(8, 6))
    
    plt.plot(weeks,best_accs['atmosphere'],label=f'Best atmosphere model',color='mediumorchid',lw=2)
    plt.scatter(weeks,best_accs['atmosphere'],color='mediumorchid')#, s=diff*100)
    plt.plot(weeks,best_accs['ocean'],label=f'Best ocean model',color='darkblue',lw=2)
    plt.scatter(weeks,best_accs['ocean'],color='darkblue')
    plt.plot(weeks,best_accs['land'],label=f'Best land model',color='darkorange',lw=2)
    plt.scatter(weeks,best_accs['land'],color='darkorange')
    
    plt.fill_between(weeks, best_accs['atmosphere'] - best_acc_ranges['atmosphere'], 
                     best_accs['atmosphere'] + best_acc_ranges['atmosphere'], color='mediumorchid', alpha=0.05)
    plt.fill_between(weeks, best_accs['ocean'] - best_acc_ranges['ocean'], 
                     best_accs['ocean'] + best_acc_ranges['ocean'], color='darkblue', alpha=0.05)
    plt.fill_between(weeks, best_accs['land'] - best_acc_ranges['land'], 
                     best_accs['land'] + best_acc_ranges['land'], color='darkorange', alpha=0.05)

    # Plot best model
    for i, j, d in zip(weeks, best_accs['atmosphere'], best_names['atmosphere']):
        plt.text(i - 0.25, 0.09, s=d, color = 'mediumorchid',fontsize=11)
    for i, j, d in zip(weeks, best_accs['ocean'], best_names['ocean']):
        plt.text(i - 0.25, 0.08, s=d, color = 'darkblue',fontsize=11)
    for i, j, d in zip(weeks, best_accs['land'], best_names['land']):
        plt.text(i - 0.25, 0.065, s=d, color = 'darkorange',fontsize=11)
    
    plt.plot(weeks, np.array(acc_persistence_wrs[weather_regime_name]), color='red', label='Persistence', ls='dashdot', lw=2)
    plt.xlim(0.4, 8.6)
    plt.ylim(0.06, 0.25)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(alpha=0.2)
    plt.ylabel('F1 Score ',fontsize=14)
    plt.xlabel('Lead time [weeks]',fontsize=14)
    # plt.legend(bbox_to_anchor=(1, 1.0), fontsize=14)
    
    plt.title(f'{weather_regime_name}',loc='left',fontsize=14)
    # plt.legend(bbox_to_anchor=(1, 0.25))
    # plt.legend(fontsize=14)
    
    plt.savefig(f'figures/f1_3comps_wr{weather_regime}.png',bbox_inches='tight')
    plt.show()
    plt.close('all')
# Out:
# ['Z500', 'U200', 'OLR', 'U10', 'U10', 'OLR', 'Z500', 'U10']
# ['OHC200', 'IC', 'OHC300', 'IC', 'IC', 'OHC100', 'SST', 'OHC100']
# ['SWVL\n7cm', 'SD', 'STL\n1m', 'SD', 'SD', 'SWVL\n1m', 'STL\n1m', 'STL\nfull']
# ['Z500', 'Z500', 'U10', 'Z500', 'Z500', 'U10', 'OLR', 'OLR']
# ['OHC50', 'OHC700', 'OHC300', 'OHC300', 'OHC100', 'OHC300', 'SSH', 'OHC300']
# ['SWVL\n28cm', 'STL\n7cm', 'SWVL\nfull', 'SWVL\nfull', 'SWVL\n1m', 'SWVL\nfull', 'STL\n1m', 'STL\n7cm']
# ['Z500', 'U200', 'OLR', 'U200', 'Z500', 'U200', 'U200', 'U200']
# ['SSH', 'OHC700', 'OHC300', 'OHC300', 'OHC100', 'OHC300', 'OHC200', 'OHC100']
# ['SWVL\n28cm', 'SD', 'SWVL\n1m', 'SD', 'SWVL\n1m', 'SWVL\nfull', 'SWVL\n1m', 'SWVL\nfull']
# ['U200', 'Z500', 'U200', 'U200', 'OLR', 'U10', 'U200', 'U200']
# ['SSH', 'SSH', 'SSH', 'SSH', 'OHC200', 'OHC300', 'OHC300', 'OHC50']
# ['STL\n28cm', 'SWVL\n1m', 'SWVL\n1m', 'SWVL\n1m', 'SWVL\n1m', 'SWVL\n7cm', 'SWVL\n7cm', 'SWVL\nfull']
# ['U200', 'OLR', 'U10', 'OLR', 'OLR', 'OLR', 'Z500', 'U200']
# ['IC', 'MLD', 'IC', 'OHC700', 'SST', 'IC', 'MLD', 'MLD']
# ['STL\n7cm', 'STL\n1m', 'STL\nfull', 'STL\n7cm', 'STL\n1m', 'STL\n1m', 'STL\n28cm', 'SD']

# %%
path_results
# Out:
# 'results/'

# %%
name_temp = 'OHC50_SODA'
week = 4
results_temp = pd.read_csv(f'{path_results}results_{name_temp}_week{week}.csv', index_col=0, parse_dates=True)

# %%
results_temp
# Out:
#             y_true  y_predicted
# 1981-01-05     3.0          4.0
# 1981-01-08     0.0          4.0
# 1981-01-12     0.0          1.0
# 1981-01-15     1.0          2.0
# 1981-01-19     3.0          2.0
# ...            ...          ...
# 2020-10-15     1.0          1.0
# 2020-10-19     2.0          1.0
# 2020-10-22     3.0          1.0
# 2020-10-26     3.0          1.0
# 2020-10-29     3.0          1.0
#
# [4156 rows x 2 columns]

# %%
plt.hist(results_temp['y_predicted'],bins= np.arange(-0.5,5),density=True)
# Out:
# (array([0.21438884, 0.21896054, 0.16097209, 0.1686718 , 0.23700674]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(results_temp['y_true'],bins= np.arange(-0.5,5),density=True)
# Out:
# (array([0.17083734, 0.23893167, 0.23652551, 0.23002887, 0.12367661]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5]),
#  <BarContainer object of 5 artists>)

# %%
np.arange(-0.5,5)
# Out:
# array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5])

# %%
for wr_temp in range(len(names_wr)):
    indices_seasons = {'Winter':[12,1,2],
                       'Spring':[3,4,5],
                       'Summer':[6,7,8],
                       'Fall':[9,10,11]}
    
    acc_persistence_seasons = {}
    for season in indices_seasons.keys():
        acc_persistence_temp = []
    
        for wk in range(1,9):
            df_temp = df_shifts[[f'week{0}',f'week{wk}']].dropna()
            df_temp = df_temp[df_temp[f'week{wk}']==wr_temp]
            df_temp = df_temp[(df_temp.index.month==indices_seasons[season][0])|\
                                        (df_temp.index.month==indices_seasons[season][1])|\
                                        (df_temp.index.month==indices_seasons[season][2])]
            acc_persistence_temp.append(accuracy_score(df_temp[f'week{0}'],df_temp[f'week{wk}']))
        acc_persistence_seasons[season] = acc_persistence_temp
    
    indices_seasons = {'Winter':[12,1,2],
                       'Spring':[3,4,5],
                       'Summer':[6,7,8],
                       'Fall':[9,10,11]}
    
    weeks = np.arange(1,9)
    for season,letter in zip(indices_seasons.keys(),['a) ','b) ','c) ','d) ']):
        for indices_component, component, label, color in zip([indices_atmosphere, indices_ocean, indices_land],
                                    ['atm','ocn','lnd'],
                                    ['atmosphere','ocean','land'],
                                    ['mediumorchid', 'darkblue', 'orange']):
            
            all_accs = []
            for ivar in range(len(indices_component)):
                name_temp = list_vars[indices_component[ivar]]
                acc_temp = []
                for week in weeks:
                    results_temp = pd.read_csv(f'{path_results}results_{name_temp}_week{week}.csv',
                                              index_col=0,parse_dates=True)
                    results_temp = results_temp[(results_temp.index.month==indices_seasons[season][0])|\
                                                (results_temp.index.month==indices_seasons[season][1])|\
                                                (results_temp.index.month==indices_seasons[season][2])]

                    results_temp = results_temp[results_temp['y_true']==wr_temp]
                    acc_temp.append(accuracy_score(results_temp['y_true'],results_temp['y_predicted']))
                all_accs.append(acc_temp)
            
            
            acc_temp = []
            for week in weeks:
                results_temp = pd.read_csv(f'{path_results}results_{component}_week{week}.csv',
                                                  index_col=0,parse_dates=True)
                results_temp = results_temp[(results_temp.index.month==indices_seasons[season][0])|\
                            (results_temp.index.month==indices_seasons[season][1])|\
                            (results_temp.index.month==indices_seasons[season][2])]
                
                results_temp = results_temp[results_temp['y_true']==wr_temp]
                acc_temp.append(accuracy_score(results_temp['y_true'],results_temp['y_predicted']))
            # plt.plot(weeks,np.array(acc_temp)*100,label=f'All {label} variables',color=color,ls='--',alpha=0.4)
            # all_accs.append(acc_temp)
            plt.plot(weeks,np.max(np.array(all_accs),axis=0)*100,label = f'Best {label} model',color=color)
            
            best_acc = np.max(np.array(all_accs),axis=0)*100
            mean_acc = np.mean(np.array(all_accs),axis=0)*100
            diffs = best_acc - mean_acc
            max_diff = 8
            min_diff = 0
            diffs = (diffs - min_diff)/(max_diff - min_diff)
            
            ind_max_acc = np.argmax(np.array(all_accs),axis=0)
            best_model = []
            for ind in ind_max_acc:
                # if ind==len(all_accs)-1:
                #     best_model.append('ALL')
                # else:
                best_model.append(' '.join(list_vars[indices_component[ind]].split('_')[:-1]))
            for i,j,d,diff in zip(weeks,np.max(np.array(all_accs),axis=0)*100,best_model,diffs):
                plt.scatter(i,j,color=color, s=diff*100)
                if component == 'lnd':
                    plt.text(i-0.32,j-5,s=d,color=color)
                else:
                    plt.text(i-0.28,j+4,s=d,color=color)
        
        plt.scatter(9,0,color='k',s=1*100,label='8% difference between best model and the mean\n accuracy of the models within each component')
        plt.scatter(9,0,color='k',s=0.125*100,label='1% difference between best model and the mean\n accuracy of the models within each component')
    
        plt.plot(weeks, np.array(acc_persistence_seasons[season][:])*100,
                 color='red',label='Persistence',ls='dashdot',lw=2)
        plt.xlim(0.6,8.4)
        plt.ylim(10,80)
        plt.grid(alpha=0.3)
        plt.ylabel('Accuracy [%]')
        plt.xlabel('Lead time [weeks]')
        
        plt.title(f'Accuracy from each component - {season} - {names_wr[wr_temp]}',
                  loc='left')
        # plt.legend(bbox_to_anchor=(1, 0.25))
        # plt.legend(fontsize=9)
    
        plt.savefig(f'figures_by_weather_regime/wr{wr_temp}_acc_3comps_{season}.png',bbox_inches='tight')
        # plt.show()
        plt.close('all')

# %%
for wr_temp in range(len(names_wr)):
    acc_persistence_temp = []

    for wk in range(1,9):
        df_temp = df_shifts[[f'week{0}',f'week{wk}']].dropna()
        df_temp = df_temp[df_temp[f'week{wk}']==wr_temp]
        acc_persistence_temp.append(accuracy_score(df_temp[f'week{0}'],df_temp[f'week{wk}']))

    weeks = np.arange(1,9)
    for indices_component, component, label, color in zip([indices_atmosphere, indices_ocean, indices_land],
                                ['atm','ocn','lnd'],
                                ['atmosphere','ocean','land'],
                                ['mediumorchid', 'darkblue', 'orange']):
        all_accs = []
        for ivar in range(len(indices_component)):
            name_temp = list_vars[indices_component[ivar]]
            acc_temp = []
            for week in weeks:
                results_temp = pd.read_csv(f'{path_results}results_{name_temp}_week{week}.csv',
                                          index_col=0,parse_dates=True)
                results_temp = results_temp[results_temp['y_true']==wr_temp]
                acc_temp.append(accuracy_score(results_temp['y_true'],results_temp['y_predicted']))
            all_accs.append(acc_temp)
            
        acc_temp = []
        for week in weeks:
            results_temp = pd.read_csv(f'{path_results}results_{component}_week{week}.csv',
                                              index_col=0,parse_dates=True)
            
            results_temp = results_temp[results_temp['y_true']==wr_temp]
            acc_temp.append(accuracy_score(results_temp['y_true'],results_temp['y_predicted']))
        # plt.plot(weeks,np.array(acc_temp)*100,label=f'All {label} variables',color=color,ls='--',alpha=0.4)
        # all_accs.append(acc_temp)
        plt.plot(weeks,np.max(np.array(all_accs),axis=0)*100,label = f'Best {label} model',color=color)
        
        best_acc = np.max(np.array(all_accs),axis=0)*100
        mean_acc = np.mean(np.array(all_accs),axis=0)*100
        diffs = best_acc - mean_acc
        max_diff = 8
        min_diff = 0
        diffs = (diffs - min_diff)/(max_diff - min_diff)
        
        ind_max_acc = np.argmax(np.array(all_accs),axis=0)
        best_model = []
        for ind in ind_max_acc:
            # if ind==len(all_accs)-1:
            #     best_model.append('ALL')
            # else:
            best_model.append(' '.join(list_vars[indices_component[ind]].split('_')[:-1]))
        for i,j,d,diff in zip(weeks,np.max(np.array(all_accs),axis=0)*100,best_model,diffs):
            plt.scatter(i,j,color=color, s=diff*100)
            if component == 'lnd':
                plt.text(i-0.32,j-5,s=d,color=color)
            else:
                plt.text(i-0.28,j+4,s=d,color=color)
    
    plt.scatter(9,0,color='k',s=1*100,label='8% difference between best model and the mean\n accuracy of the models within each component')
    plt.scatter(9,0,color='k',s=0.125*100,label='1% difference between best model and the mean\n accuracy of the models within each component')

    plt.plot(weeks, np.array(acc_persistence_temp[:])*100,
             color='red',label='Persistence',ls='dashdot',lw=2)
    plt.xlim(0.6,8.4)
    plt.ylim(10,80)
    plt.grid(alpha=0.3)
    plt.ylabel('Accuracy [%]')
    plt.xlabel('Lead time [weeks]')
    
    plt.title(f'Accuracy from each component - {names_wr[wr_temp]}',
              loc='left')
    # plt.legend(bbox_to_anchor=(1, 0.25))
    # plt.legend(fontsize=9)

    plt.savefig(f'figures_by_weather_regime/wr{wr_temp}_acc_3comps.png',bbox_inches='tight')
    # plt.show()
    plt.close('all')

# %% [markdown]
# # Check for ENSO

# %%
col_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df_oni = pd.read_csv('https://psl.noaa.gov/data/correlation/oni.data', sep='\s+', skiprows=1, names=col_names) 
df_oni = df_oni.apply(pd.to_numeric, errors='coerce')
df_oni = df_oni.iloc[:-9]
# df_oni=df_oni.dropna(inplace=True)
# df_oni=df_oni.replace({-99.90 : np.NaN}, inplace=True)
stacked_series = df_oni.stack()
df_oni_stacked = stacked_series.to_frame()
df_oni_stacked.reset_index(inplace=True)
df_oni_stacked.columns = ['Year', 'Month', 'ONI']
df_oni_stacked['Date'] = pd.to_datetime(df_oni_stacked['Year'] + '-' + df_oni_stacked['Month'])
df_oni_stacked['Date'] = df_oni_stacked['Date'].dt.strftime('%Y-%m')
df_oni_stacked.set_index('Date', inplace=True)
df_oni_stacked.drop(['Year', 'Month'], axis=1, inplace=True)
df_oni_stacked.index = pd.to_datetime(df_oni_stacked.index)

serie_oni = []
for i in range(len(df_shifts.index)):
    date_temp = df_shifts.index[i]
    serie_oni.append(df_oni_stacked.loc[f'{date_temp.year}-{str(date_temp.month).zfill(2)}']\
            .values[0][0])
    
df_shifts['ONI'] = serie_oni
df_oni = df_shifts[['ONI']]

# %%
names_states = ['Niño','Neutral','Niña']

acc_persistence_enso = {}
for state in names_states:
    acc_persistence_temp = []

    for wk in range(1,9):
        df_temp = df_shifts[[f'week{0}',f'week{wk}']].dropna()
        
        df_temp = pd.concat([df_temp,df_oni],axis=1).dropna()
        if state == 'Niño':
            df_temp = df_temp[df_temp['ONI']>=0.5]
        elif state == 'Neutral':
            df_temp = df_temp[(df_temp['ONI']>-0.5)&(df_temp['ONI']<0.5)]
        elif state == 'Niña':
            df_temp = df_temp[df_temp['ONI']<=-0.5]
        else:
            break
            
        acc_persistence_temp.append(accuracy_score(df_temp[f'week{0}'],df_temp[f'week{wk}']))
        
    acc_persistence_enso[state] = acc_persistence_temp

# %%
weeks = np.arange(1,9)
for state in names_states:
    for indices_component, component, label, color in zip([indices_atmosphere, indices_ocean, indices_land],
                                ['atm','ocn','lnd'],
                                ['atmosphere','ocean','land'],
                                ['mediumorchid', 'darkblue', 'orange']):
        
        all_accs = []
        for ivar in range(len(indices_component)):
            name_temp = list_vars[indices_component[ivar]]
            acc_temp = []
            for week in weeks:
                results_temp = pd.read_csv(f'{path_results}results_{name_temp}_week{week}.csv',
                                          index_col=0,parse_dates=True)
                
                results_temp = pd.concat([results_temp,df_oni],axis=1).dropna()
                if state == 'Niño':
                    results_temp = results_temp[results_temp['ONI']>=0.5]
                elif state == 'Neutral':
                    results_temp = results_temp[(results_temp['ONI']>-0.5)&(results_temp['ONI']<0.5)]
                elif state == 'Niña':
                    results_temp = results_temp[results_temp['ONI']<=-0.5]
                else:
                    break
                acc_temp.append(accuracy_score(results_temp['y_true'],results_temp['y_predicted']))
            all_accs.append(acc_temp)
        
        
        acc_temp = []
        for week in weeks:
            results_temp = pd.read_csv(f'{path_results}results_{component}_week{week}.csv',
                                              index_col=0,parse_dates=True)
            results_temp = pd.concat([results_temp,df_oni],axis=1).dropna()
            if state == 'Niño':
                results_temp = results_temp[results_temp['ONI']>=0.5]
            elif state == 'Neutral':
                results_temp = results_temp[(results_temp['ONI']>-0.5)&(results_temp['ONI']<0.5)]
            elif state == 'Niña':
                results_temp = results_temp[results_temp['ONI']<=-0.5]
            else:
                break
            acc_temp.append(accuracy_score(results_temp['y_true'],results_temp['y_predicted']))
        # plt.plot(weeks,np.array(acc_temp)*100,label=f'All {label} variables',color=color,ls='--',alpha=0.4)
        all_accs.append(acc_temp)
        plt.plot(weeks,np.max(np.array(all_accs),axis=0)*100,label = f'Best {label} model',color=color)
        
        ind_max_acc = np.argmax(np.array(all_accs),axis=0)
        best_model = []
        for ind in ind_max_acc:
            if ind==len(all_accs)-1:
                best_model.append('ALL')
            else:
                best_model.append(' '.join(list_vars[indices_component[ind]].split('_')[:-1]))
        for i,j,d in zip(weeks,np.max(np.array(all_accs),axis=0)*100,best_model):
            plt.scatter(i,j,color=color)
            plt.text(i-0.25,j+0.27,s=d,color=color)
        
        plt.plot(weeks, np.array(acc_persistence_enso[state][:])*100,
             color='red',label='Persistence',ls='dashdot',lw=2)
    # plt.xlim(1,8)
    plt.ylim(19,40)
    plt.grid(alpha=0.3)
    plt.ylabel('Accuracy [%]')
    # plt.xlabel('Duration (weeks)')
    plt.title(f'Accuracy from each component - {state}: ',loc='left')
    plt.savefig(f'figures/acc_3comps_{state}.png'.replace('ñ','n'),bbox_inches='tight')
    # plt.legend(bbox_to_anchor=(1, 0.25))
    plt.show()
    plt.close('all')

# %%
list_files_scores_val = np.sort(glob.glob(f'{path_results}*_scores_val.npy'))
list_files_scores_test = np.sort(glob.glob(f'{path_results}*_scores_test.npy'))

# %%
names_vars = np.array([list_files_scores_val[i].split('/')[-1].split('_s')[0] for i in range(len(list_files_scores_val))])

# %%
indices_atmosphere = np.array([8,20,21,22,23])
indices_land = np.array([9,12,13,14,15,16,17,18,19,24])
indices_ocean = np.array([2,3,4,5,6,7,10,11,25])

# %%
weeks = np.arange(1,9)

# %%
path_figures_accuracy = 'figures_random_forest/accuracy/'

# %%
for ivar in indices_atmosphere:
    scores_val = np.load(list_files_scores_val[ivar])
    if names_vars[ivar]=='atm':
        plt.plot(weeks[1:],scores_val[1:]*100,label = names_vars[ivar],color='k')
    else:
        plt.plot(weeks[1:],scores_val[1:]*100,label = names_vars[ivar],alpha=0.8)
plt.plot(weeks[1:],acc_persistence[1:]*100,label = 'persistence',color='gray',ls = '--')
plt.ylim(20,27)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.legend(bbox_to_anchor=(1, 1.0))
plt.savefig(f'{path_figures_accuracy}atm_val_acc.png',bbox_inches='tight')

plt.close('all')
for ivar in indices_ocean:
    scores_val = np.load(list_files_scores_val[ivar])
    if names_vars[ivar]=='ocn':
        plt.plot(weeks[1:],scores_val[1:]*100,label = names_vars[ivar],color='k')
    else:
        plt.plot(weeks[1:],scores_val[1:]*100,label = names_vars[ivar],alpha=0.8)
plt.plot(weeks[1:],acc_persistence[1:]*100,label = 'persistence',color='gray',ls = '--')
plt.ylim(20,27)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.legend(bbox_to_anchor=(1.3, 1.0))
plt.savefig(f'{path_figures_accuracy}ocn_val_acc.png',bbox_inches='tight')

plt.close('all')
for ivar in indices_land:
    scores_val = np.load(list_files_scores_val[ivar])
    if names_vars[ivar]=='lnd':
        plt.plot(weeks[1:],scores_val[1:]*100,label = names_vars[ivar],color='k')
    else:
        plt.plot(weeks[1:],scores_val[1:]*100,label = names_vars[ivar],alpha=0.8)
plt.plot(weeks[1:],acc_persistence[1:]*100,label = 'persistence',color='gray',ls = '--')
plt.ylim(20,27)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.legend(bbox_to_anchor=(1., 1))
plt.savefig(f'{path_figures_accuracy}lnd_val_acc.png',bbox_inches='tight')
plt.close('all')

# %%
for ivar in indices_atmosphere:
    scores_test = np.load(list_files_scores_test[ivar])
    if names_vars[ivar]=='atm':
        plt.plot(weeks[1:],scores_test[1:]*100,label = names_vars[ivar],color='k')
    else:
        plt.plot(weeks[1:],scores_test[1:]*100,label = names_vars[ivar],alpha=0.8)
plt.plot(weeks[1:],acc_persistence[1:]*100,label = 'persistence',color='gray',ls = '--')
plt.ylim(16,32)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.legend(bbox_to_anchor=(1, 1.0))
plt.savefig(f'{path_figures_accuracy}atm_test_acc.png',bbox_inches='tight')

plt.close('all')
for ivar in indices_ocean:
    scores_test = np.load(list_files_scores_test[ivar])
    if names_vars[ivar]=='ocn':
        plt.plot(weeks[1:],scores_test[1:]*100,label = names_vars[ivar],color='k')
    else:
        plt.plot(weeks[1:],scores_test[1:]*100,label = names_vars[ivar],alpha=0.8)
plt.plot(weeks[1:],acc_persistence[1:]*100,label = 'persistence',color='gray',ls = '--')
plt.ylim(16,32)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.legend(bbox_to_anchor=(1.3, 1.0))
plt.savefig(f'{path_figures_accuracy}ocn_test_acc.png',bbox_inches='tight')

plt.close('all')
for ivar in indices_land:
    scores_test = np.load(list_files_scores_test[ivar])
    if names_vars[ivar]=='lnd':
        plt.plot(weeks[1:],scores_test[1:]*100,label = names_vars[ivar],color='k')
    else:
        plt.plot(weeks[1:],scores_test[1:]*100,label = names_vars[ivar],alpha=0.8)
plt.plot(weeks[1:],acc_persistence[1:]*100,label = 'persistence',color='gray',ls = '--')
plt.ylim(16,32)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.legend(bbox_to_anchor=(1., 1))
plt.savefig(f'{path_figures_accuracy}lnd_test_acc.png',bbox_inches='tight')
plt.close('all')

# %%
for ivar in [23,24,25]:
    scores_val = np.load(list_files_scores_val[ivar])
    # if names_vars[ivar]=='lnd':
    #     plt.plot(weeks,scores_val,label = names_vars[ivar],color='k')
    # else:
    plt.plot(weeks[1:],scores_val[1:]*100,label = names_vars[ivar])
        
plt.xlabel('week')
plt.ylabel('accuracy')
plt.legend()
plt.ylim(21,27)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.savefig(f'{path_figures_accuracy}acc_comps_val.png',bbox_inches='tight')
# plt.close('all')

# %%
for ivar in [23,24,25]:
    scores_test = np.load(list_files_scores_test[ivar])
    # if names_vars[ivar]=='lnd':
    #     plt.plot(weeks,scores_val,label = names_vars[ivar],color='k')
    # else:
    plt.plot(weeks[1:],scores_test[1:]*100,label = names_vars[ivar])
        
plt.xlabel('week')
plt.ylabel('accuracy')
plt.legend()
plt.ylim(17,30)
plt.grid(alpha=0.3)
plt.ylabel('Accuracy [%]')
# plt.xlabel('Duration (weeks)')
plt.title('Seasonal changes in accuracy: ',loc='left')
plt.savefig(f'{path_figures_accuracy}acc_comps_test.png',bbox_inches='tight')
# plt.close('all')

# %%
ds = xr.open_dataset('/glade/scratch/jhayron/Data4Predictability/WeeklyAnoms_DetrendedStd/Z500_ERA5_Region.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 240, lon: 720, time: 4164)
# Coordinates:
#     level        float64 500.0
#   * lat          (lat) float64 -29.75 -29.25 -28.75 -28.25 ... 88.75 89.25 89.75
#   * lon          (lon) float64 0.25 0.75 1.25 1.75 ... 358.2 358.8 359.2 359.8
#   * time         (time) datetime64[ns] 1981-01-05 1981-01-08 ... 2020-11-26
# Data variables:
#     Z_anomalies  (time, lat, lon) float64 ...

# %%
ds.isel(time=0).Z_anomalies
# Out:
# <xarray.DataArray 'Z_anomalies' (lat: 240, lon: 720)>
# [172800 values with dtype=float64]
# Coordinates:
#     level    float64 500.0
#   * lat      (lat) float64 -29.75 -29.25 -28.75 -28.25 ... 88.75 89.25 89.75
#   * lon      (lon) float64 0.25 0.75 1.25 1.75 2.25 ... 358.2 358.8 359.2 359.8
#     time     datetime64[ns] 1981-01-05
# Attributes:
#     regrid_method:  nearest_s2d
#     units:          m^2/s^2
#     File Author:    Jhayron S. Pérez-Carrasquilla

# %%
import cartopy
import cartopy.crs as ccrs
import cartopy.feature
import cartopy.feature as cfeature
import cartopy.feature as cf
import cartopy.io.shapereader as shpreader

# %%
##########PLOT#####################
fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111,projection=ccrs.PlateCarree(central_longitude=-90+360))

# vmax = np.round(abs(trend[f'{names_variables[iname]}_trend']).max(),2)
# vmin = -np.round(abs(trend[f'{names_variables[iname]}_trend']).max(),0)

vmax = 1
vmin = -1
# print(vmax,vmin)
cs = plt.pcolormesh(ds.isel(time=0).lon,ds.isel(time=0).lat,\
    ds.isel(time=0).Z_anomalies/9.8,cmap='seismic',
    transform=ccrs.PlateCarree(),vmin=vmin,vmax=vmax)
ax.coastlines(resolution='110m', color='k', linewidth=0.75, zorder=10)
ax.margins(x=0, y=0)

plt.xlim()
plt.title('Z500 anomalies')

cbar_ax = fig.add_axes([0.25, 0.26, 0.5, 0.0175])
# ticks_1 = [-80, -40, 0, 40, 80]
cbar = fig.colorbar(cs, cax=cbar_ax,
                    orientation='horizontal', extend='both')
cbar.ax.tick_params(labelsize=14)
cbar.set_label('m', fontsize=14)

# %%
len()
